# %% [markdown]
# # Ch 10 - Syntax Drills
#
# Cells will be filled in live during the next session. Objectives for Ch 10:
#
# - pathlib basics
# - open / read / write
# - working directory navigation
# - shutil copy / move / delete
# - walking trees with `os.walk` or `pathlib.rglob`
